# %% [markdown]
# <a href="https://colab.research.google.com/github/divyansh212/100-Days-of-python-coding/blob/main/09programming_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Travel_Log={
    "France":["Paris","Lillie","Dijon"],
    "Germany":["Stuttgrat","Berlin","Munich"],
}
print(Travel_Log["France"][1])
# Out:
# Lillie

# %%
nested_list=["A","B",["C","D"]]
print(nested_list[2][1])
# Out:
# D

# %%
Travel_Log={
    "France":{
        "cities_visited":["Paris","Lillie","Dijon"],
        "num_times_visited":1243
        },
    "Germany":{
        "cities_visited":["Stuttgrat","Berlin","Munich","Hamburg"],
        "num_of_times_visited ": 1939,
        },
}
print(Travel_Log["Germany"]["cities_visited"][0])
# Out:
# Stuttgrat

# %%
print("Welcome to the silent Auction")
print('''
                         ___________
                          )        /
                          )_______(
                          |       |_.-._,.---------.,_.-._
                          |       | | |               | | '-.
                          |       |_| |_             _| |_..-'
                          |_______| '-'---------'' '-'
                          /       \\
                         /_________\\
                        /----------- \.
                      /_______________\\
''')
auction_list={}
user_name=input("what is your name\n =>")
what_is_your_bid=int(input("Enter your bid\n =>$ "))
print("\n"*1000)
auction_list[user_name]=what_is_your_bid
other_user=input("are there any other user\n =").lower()
while other_user!="no":
  user_name=input("what is your name\n =>")
  what_is_your_bid=int(input("Enter your bid\n =>$ "))
  print("\n"*100)
  auction_list[user_name]=what_is_your_bid
  other_user=input("are there any other user\n =").lower()
print(auction_list)
max(auction_list,key=auction_list.get)
def bidding_acution(auction_list):
  highest_bid=0
  winner=''
  for bidder in auction_list:
    biding_amount=auction_list[bidder]
    if biding_amount>highest_bid:
      highhest_bid=biding_amount
      winner=user_name
  print(f"The winner of this Auction is {winner} with the bid amount of ${highhest_bid} ")
bidding_acution(auction_list)
# Out:
# Welcome to the silent Auction
#
#                          ___________
#                           )        /
#                           )_______(
#                           |       |_.-._,.---------.,_.-._
#                           |       | | |               | | '-.
#                           |       |_| |_             _| |_..-'
#                           |_______| '-'---------'' '-'
#                           /       \
#                          /_________\
#                         /----------- \.
#                       /_______________\
#
# what is your name
#  =>d
# Enter your bid
#  =>$ 123
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ...
